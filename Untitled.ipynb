# %%
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()
file_paths = filedialog.askopenfilenames(title="Select WhatsApp .crypt15 files")
file_paths = list(file_paths)
print("Selected files:", file_paths)
